# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/cleaned_global_water_consumption.csv")
df.head()
# Out:
#      Country  Year  Per Capita Water Use (Liters per Day)  \
# 0  Argentina  2000                             235.431429
# 1  Argentina  2001                             299.551000
# 2  Argentina  2002                             340.124615
# 3  Argentina  2003                             326.756667
# 4  Argentina  2004                             230.346000
#
#    Agricultural Water Use (%)  Industrial Water Use (%)  \
# 0                   48.550000                 20.844286
# 1                   48.465000                 26.943000
# 2                   50.375385                 29.042308
# 3                   49.086667                 30.476000
# 4                   38.670000                 36.670000
#
#    Household Water Use (%)  Rainfall Impact (Annual Precipitation in mm)  \
# 0                30.100000                                   1288.698571
# 1                22.550000                                   1371.729000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Country                                         500 non-null    object
#  1   Year                                            500 non-null    int64
#  2   Per Capita Water Use (Liters per Day)           500 non-null    float64
#  3   Agricultural Water Use (%)                      500 non-null    float64
#  4   Industrial Water Use (%)                        500 non-null    float64
#  5   Household Water Use (%)                         500 non-null    float64
#  6   Rainfall Impact (Annual Precipitation in mm)    500 non-null    float64
#  7   Groundwater Depletion Rate (%)                  500 non-null    float64
#  8   Total Water Consumption (Billion Cubic Meters)  500 non-null    float64
# ...

# %%
df["Total Water Consumption (Billion Cubic Meters)"].sum()
# Out:
# np.float64(250612.2150901)

# %%
df.describe()
# Out:
#               Year  Per Capita Water Use (Liters per Day)  \
# count   500.000000                             500.000000
# mean   2012.000000                             276.004782
# std       7.218324                              42.669593
# min    2000.000000                             111.708333
# 25%    2006.000000                             250.225406
# 50%    2012.000000                             276.430556
# 75%    2018.000000                             300.221750
# max    2024.000000                             404.350000
#
#        Agricultural Water Use (%)  Industrial Water Use (%)  \
# count                  500.000000                500.000000
# mean                    50.180829                 27.792837
# std                      5.566886                  4.361660
# min                     28.905000                 13.276667
# 25%                     46.513611                 25.018000
# 50%                     50.318482                 27.648539
# ...

# %%
df.isnull()
# Out:
#      Country   Year  Per Capita Water Use (Liters per Day)  \
# 0      False  False                                  False
# 1      False  False                                  False
# 2      False  False                                  False
# 3      False  False                                  False
# 4      False  False                                  False
# ..       ...    ...                                    ...
# 495    False  False                                  False
# 496    False  False                                  False
# 497    False  False                                  False
# 498    False  False                                  False
# 499    False  False                                  False
#
#      Agricultural Water Use (%)  Industrial Water Use (%)  \
# 0                         False                     False
# 1                         False                     False
# 2                         False                     False
# ...

# %%
df.isnull().sum()
# Out:
# Country                                           0
# Year                                              0
# Per Capita Water Use (Liters per Day)             0
# Agricultural Water Use (%)                        0
# Industrial Water Use (%)                          0
# Household Water Use (%)                           0
# Rainfall Impact (Annual Precipitation in mm)      0
# Groundwater Depletion Rate (%)                    0
# Total Water Consumption (Billion Cubic Meters)    0
# dtype: int64

# %%
df.drop(columns=["Year"],inplace=True)
df.head()
# Out:
#      Country  Per Capita Water Use (Liters per Day)  \
# 0  Argentina                             235.431429
# 1  Argentina                             299.551000
# 2  Argentina                             340.124615
# 3  Argentina                             326.756667
# 4  Argentina                             230.346000
#
#    Agricultural Water Use (%)  Industrial Water Use (%)  \
# 0                   48.550000                 20.844286
# 1                   48.465000                 26.943000
# 2                   50.375385                 29.042308
# 3                   49.086667                 30.476000
# 4                   38.670000                 36.670000
#
#    Household Water Use (%)  Rainfall Impact (Annual Precipitation in mm)  \
# 0                30.100000                                   1288.698571
# 1                22.550000                                   1371.729000
# 2                23.349231                                   1590.305385
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df["Country"] = label_encoder.fit_transform(df["Country"])
df.head()
# Out:
#    Country  Per Capita Water Use (Liters per Day)  Agricultural Water Use (%)  \
# 0        0                             235.431429                   48.550000
# 1        0                             299.551000                   48.465000
# 2        0                             340.124615                   50.375385
# 3        0                             326.756667                   49.086667
# 4        0                             230.346000                   38.670000
#
#    Industrial Water Use (%)  Household Water Use (%)  \
# 0                 20.844286                30.100000
# 1                 26.943000                22.550000
# 2                 29.042308                23.349231
# 3                 30.476000                24.440000
# 4                 36.670000                23.924000
#
#    Rainfall Impact (Annual Precipitation in mm)  \
# 0                                   1288.698571
# 1                                   1371.729000
# ...

# %%
x=df.iloc[:,0:7]
x
# Out:
#      Country  Per Capita Water Use (Liters per Day)  \
# 0          0                             235.431429
# 1          0                             299.551000
# 2          0                             340.124615
# 3          0                             326.756667
# 4          0                             230.346000
# ..       ...                                    ...
# 495       19                             292.970000
# 496       19                             275.978000
# 497       19                             292.039000
# 498       19                             261.197500
# 499       19                             186.374000
#
#      Agricultural Water Use (%)  Industrial Water Use (%)  \
# 0                     48.550000                 20.844286
# 1                     48.465000                 26.943000
# 2                     50.375385                 29.042308
# 3                     49.086667                 30.476000
# ...

# %%
y = df["Total Water Consumption (Billion Cubic Meters)"]
y
# Out:
# 0      481.490000
# 1      455.063000
# 2      482.749231
# 3      452.660000
# 4      634.566000
#           ...
# 495    418.097000
# 496    572.094000
# 497    440.978000
# 498    566.865000
# 499    249.485000
# Name: Total Water Consumption (Billion Cubic Meters), Length: 500, dtype: float64

# %%
sns.histplot(df["Total Water Consumption (Billion Cubic Meters)"])
plt.plot()
# Out:
# []

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
ypred = model.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_error,r2_score
mae = mean_absolute_error(ytest, ypred)
r2 = r2_score(ytest, ypred)
print("Mean Absolute Error:", mae)
print("R-squared Score:", r2)
# Out:
# Mean Absolute Error: 75.50742849028943
# R-squared Score: -0.017069304961054188
